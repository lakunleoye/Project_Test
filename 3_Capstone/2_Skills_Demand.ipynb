# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df ['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_UK = df[df['job_country'] == 'United Kingdom']

# %%
df_skills = df_UK.explode('job_skills')
df_skills[['job_title', 'job_skills']]
# Out:
#                                                 job_title  job_skills
# 15                                          Data Engineer      python
# 15                                          Data Engineer         sql
# 15                                          Data Engineer    power bi
# 45                                    Senior Data Analyst         sql
# 45                                    Senior Data Analyst      python
# ...                                                   ...         ...
# 785642  Submission for the position: Data Engineer Sen...        qlik
# 785642  Submission for the position: Data Engineer Sen...  confluence
# 785642  Submission for the position: Data Engineer Sen...        jira
# 785676                              Senior Data Scientist           r
# 785676                              Senior Data Scientist      python
#
# [167546 rows x 2 columns]

# %%
df_skills_count = df_skills.groupby(['job_skills', 'job_title_short']).size()

df_skills_count = df_skills_count.reset_index(name='skills_count')

df_skills_count.sort_values('skills_count', ascending=False, inplace=True)

df_skills_count
# Out:
#        job_skills            job_title_short  skills_count
# 1163          sql              Data Engineer          7050
# 915        python              Data Engineer          6462
# 916        python             Data Scientist          6329
# 88          azure              Data Engineer          4865
# 1162          sql               Data Analyst          4467
# ...           ...                        ...           ...
# 786     openstack          Software Engineer             1
# 783        opencv          Software Engineer             1
# 780        opencv  Machine Learning Engineer             1
# 775   objective-c               Data Analyst             1
# 1418         zoom          Software Engineer             1
#
# [1419 rows x 3 columns]

# %%
job_titles = df_skills_count['job_title_short'].unique()

job_titles = sorted(job_titles[:3])

job_titles
# Out:
# ['Data Analyst', 'Data Engineer', 'Data Scientist']

# %%
fig, ax = plt.subplots(len(job_titles), 1)

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_count[df_skills_count['job_title_short'] == job_title].head(5)
    df_plot.plot(kind='barh', x='job_skills', y='skills_count', ax=ax[i], title= job_title)
    ax[i].invert_yaxis()
    ax[i].set_ylabel('')
    ax[i].legend().set_visible(False)

fig.suptitle('Counts of Top Skills in Job Postings', fontsize=15)
fig.tight_layout(h_pad=0.5)
plt.show()

# %% [markdown]
# # Converting the Job Counts to Percentage

# %%
df_job_title_counts = df_UK['job_title_short'].value_counts().reset_index(name='jobs_total')

# %%
df_skills_percent = pd.merge(df_skills_count, df_job_title_counts, how='left', on='job_title_short' )

df_skills_percent['skills_percent'] = 100 * df_skills_percent['skills_count']/df_skills_percent['jobs_total']

df_skills_percent
# Out:
#        job_skills            job_title_short  skills_count  jobs_total  \
# 0             sql              Data Engineer          7050       11807
# 1          python              Data Engineer          6462       11807
# 2          python             Data Scientist          6329        9148
# 3           azure              Data Engineer          4865       11807
# 4             sql               Data Analyst          4467       10482
# ...           ...                        ...           ...         ...
# 1414    openstack          Software Engineer             1         541
# 1415       opencv          Software Engineer             1         541
# 1416       opencv  Machine Learning Engineer             1         317
# 1417  objective-c               Data Analyst             1       10482
# 1418         zoom          Software Engineer             1         541
#
#       skills_percent
# 0          59.710341
# 1          54.730245
# 2          69.184521
# 3          41.204370
# ...

# %%
fig, ax = plt.subplots(len(job_titles), 1)

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_percent[df_skills_percent['job_title_short'] == job_title].head(5)
    # df_plot.plot(kind='barh', x='job_skills', y='skills_percent', ax=ax[i], title= job_title) #(Matplotlib prompt)
    sns.barplot(data=df_plot, y='job_skills', x='skills_percent',ax=ax[i], hue='skills_percent', palette='dark:r_r')
    ax[i].set_title(job_title)
    ax[i].set_ylabel('')
    ax[i].set_xlabel('')
    ax[i].get_legend().remove()
    ax[i].set_xlim(0, 80)
      
    for n, v in enumerate(df_plot['skills_percent']):
       ax[i].text(v + 1, n, f'{v: .0f}%', va='center')

    if i != len(job_titles) - 1:
       ax[i].set_xticks([]) 
    


sns.set_theme(style='ticks')
fig.suptitle('Likelihood of Skills requested in Job Postings', fontsize=15)
fig.tight_layout(h_pad=0.5)
plt.show()
